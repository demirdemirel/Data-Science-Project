# %%
# Importing the libraries
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# Importing the dataset
dataset = pd.read_csv('locations.csv')


# Scatter-plot
lng = dataset.Longitude
lat = dataset.Latitude

# Mercator projection

def lat_lng_to_pixels(lat, lng):
    lat_rad = lat * np.pi / 180.0
    lat_rad = np.log(np.tan((lat_rad + np.pi / 2.0) / 2.0))
    x = 100 * (lng + 180.0) / 360.0
    y = 100 * (lat_rad - np.pi) / (2.0 * np.pi)
    return (x, y)

px, py = lat_lng_to_pixels(lat, lng)

layout = dict(
        colorbar = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 0.5
        ),
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-94-922cf763a1f1> in <module>()
#       1 # Importing the libraries
# ----> 2 from mpl_toolkits.basemap import Basemap
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
dataset.head()
# Out:
#    zip code  Latitude  Longitude
# 0     48067   42.4906   -83.1366
# 1     70072   29.8598   -90.1105
# 2     55117   44.9995   -93.0969
# 3      2460   42.3520   -71.2084
# 4     55455   44.9735   -93.2331

# %%
plt.figure(figsize=(30, 30))
plt.scatter(px, py, s=5.9, alpha=1.)
plt.axis('equal')
plt.xlim(15.5, 32,5)
plt.ylim(-39.5, -37.5)
plt.axis('off')
# Out:
# (15.5, 32.0, -39.5, -37.5)
